# %% [markdown]
# <a href="https://colab.research.google.com/github/LucioFassarella/Qiskit/blob/main/Qiskit_EstimativaFase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Qiskit
#
# ---
#
# <font color = "yellow">**Qiskit**:</font>
# *   [Python's Instalation](https://pypi.org/project/qiskit/)
# *   [IBM Quantum cloud](https://quantum.cloud.ibm.com/)
#     *   [Qiskit connect](https://cloud.ibm.com/docs/quantum-computing?topic=quantum-computing-get-started) (IBM Runtime Service)
#        *   [Getting Started](https://cloud.ibm.com/docs/quantum-computing?topic=quantum-computing-get-started)
# *   [Qiskit](https://docs.quantum.ibm.com/api/qiskit)
#     *   [Qiskit Circuit Library](https://docs.quantum.ibm.com/api/qiskit/circuit_library)
#     *   [Qiskit Gates Tutorial](https://github.com/Qiskit/qiskit-tutorials/blob/master/tutorials/circuits/3_summary_of_quantum_operations.ipynb)
#     *   [List of Quantum Logic Gates](https://en.wikipedia.org/wiki/List_of_quantum_logic_gates)
#
# [<font color="yellow">**Execution modes**</font>](https://quantum.cloud.ibm.com/docs/en/guides/execution-modes)
#
# *	[Choose the execution mode](https://quantum.cloud.ibm.com/docs/en/guides/choose-execution-mode)
# *   [Single Job](https://quantum.cloud.ibm.com/docs/en/guides/primitives-examples#estimator-examples)
# *	[Batch mode](https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-batch)
# *	[Section mode](https://quantum.cloud.ibm.com/docs/en/guides/run-jobs-session)
# *	[Primitives examples](https://quantum.cloud.ibm.com/docs/en/guides/primitives-examples)
#
#
# [<font color="yellow">**Local simulators**</font>](https://quantum.cloud.ibm.com/docs/en/migration-guides/local-simulators)
#
# ---
#
# ⏬
#
# *	**Qiskit**:
# 	*	*How can I create a custom gate from a matrix? 1 Minute Qiskit*. Youtube, 05 set. 2022.
#             Url: [https://youtu.be/zFgyMGklANM?si=oCxxGYBFQ0OCoCaL](https://youtu.be/zFgyMGklANM?si=oCxxGYBFQ0OCoCaL).
# 	*	*How do I convert a circuito to a Gate? 1 Minute Qiskit*. Youtube, 20 abr. 2020.
#             Url: [https://youtu.be/krhPpzkT_z4?si=baTxDQKybfb1SQHZ](https://youtu.be/krhPpzkT_z4?si=baTxDQKybfb1SQHZ).
# 	*	*How can I create a custom controlled gate? - 1 Minute Qiskit*. Youtube, 31 out. 2022. Url:
#             [https://youtu.be/wHQiB95hu-E?si=toFulZ7ngFyb5F6_](https://youtu.be/wHQiB95hu-E?si=toFulZ7ngFyb5F6_).

# %% [markdown]
# $$
# e^{i\theta} = e^{i2\pi \theta/2\pi} = e^{i2\pi\varphi}
# $$

# %% [markdown]
# ## QISKIT: Carregamento

# %%
# !pip install qiskit -U
# !pip install qiskit_aer -U
# !pip install qiskit-ibm-runtime -U

# !pip install matplotlib
# !pip install pylatexenc

import qiskit
qiskit.__version__
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 84.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.4/377.4 kB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=acd6323359db433cc1a8281f9cefa04c12163d0e169223e3cffa0525a19fde6e
# ...

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

'''
## Save account to disk and save it as the default.
#QiskitRuntimeService.save_account(channel="ibm_cloud", token="<IBM Cloud API key>", instance="<IBM Cloud CRN>", name="account-name", set_as_default=True)

## Load the saved credentials
#service = QiskitRuntimeService(name="account-name")
'''

# Conecção com a IBM

# token_privado = "..." # <-- Inserir token privado na IBM
# instance_do_projeto = "..." # <-- Inserir instance do projeto

# from qiskit_ibm_runtime import QiskitRuntimeService
# service = QiskitRuntimeService(
#     channel="ibm_cloud",
#     token = token_privado,
#     instance = instance_do_projeto
#     )
# Out:
# '\n## Save account to disk and save it as the default.\n#QiskitRuntimeService.save_account(channel="ibm_cloud", token="<IBM Cloud API key>", instance="<IBM Cloud CRN>", name="account-name", set_as_default=True)\n\n## Load the saved credentials\n#service = QiskitRuntimeService(name="account-name")\n'

# %%
# Qiskit: métodos básicos

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister

from qiskit import transpile

from qiskit.visualization import plot_histogram, array_to_latex, plot_state_city

# %% [markdown]
# ## Método de Primitivos

# %%
def qiskit_sampler(circuito_com_medidas, shots = None, backend = None):
    '''
    Método para executar o Sampler
    >>> O Sampler realiza medidas em circuitos quânticos e retorna a contagem de qubits.
        A partir dos resultados do Sampler, podemos estimar as probabilidade de cada resultado.

    Input:
        circuito : circuito quântico que prepara um estado de qubits
        backend  : backend para rodar o Sampler

    Saída:
        resultado do Sampler

    Observação: os resultados do Sampler são rotulados pelo nomes dos registros clássicos.
                Para um circuito com medidas definidas por 'measure_all', o rótulo é 'meas'.
                Para circuitos com medidas definidas de início sem denominação explícita,
                os rótulos são 'c', 'c1', 'c2', etc.

    Tutorial do Sampler: https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/sampler-v2
    '''

    # Importação de métodos e backend

    from qiskit_ibm_runtime import SamplerV2 as Sampler

    if backend is None:
        from qiskit_ibm_runtime.fake_provider import FakeBrisbane
        backend = FakeBrisbane()
    else:
        backend = backend

    from qiskit.transpiler import generate_preset_pass_manager
    pm = generate_preset_pass_manager(optimization_level=2, backend = backend)

    # Transpilação

    isa_circuitos = pm.run(circuito_com_medidas)

    if shots is None:
        shots = 2**10
    else:
        shots = shots

    sampler = Sampler(backend)
    job = sampler.run([(isa_circuitos, )], shots = shots)
    result = job.result()

    # Identificação do nome do primeiro registro clássico
    classical_register_name = isa_circuitos.cregs[0].name
    counts = result[0].data[classical_register_name].get_counts()

    return counts, result

def qiskit_estimator(circuito_sem_medidas, hamiltoniano, precisao = None, backend = None):
    '''
    Método para executar o Estimator
    >>> O Estimator estima valores esperados de circuitos e observáveis.

    Input:
        circuito : circuito quântico que prepara um estado de qubits
        hamiltoniano (SparsePauliOp): hamiltoniano a ser medido
        precisao (float): precisão do resultado
        backend  : backend para rodar o Estimator

    Saída:
        resultado do Estimator

    Tutorial do EstimatorV2: https://quantum.cloud.ibm.com/docs/en/api/qiskit-ibm-runtime/estimator-v2
    '''

    # Importação de métodos e backend

    from qiskit_ibm_runtime import EstimatorV2 as Estimator
    from qiskit.transpiler import generate_preset_pass_manager

    # Use the existing service object
    # service = QiskitRuntimeService()
    if backend is None:
        from qiskit_ibm_runtime.fake_provider import FakeBrisbane
        backend = FakeBrisbane()
    else:
        backend = backend

    if precisao is None:
        precisao = 2**(-10)
    else:
        precisao = precisao

    # Transpilação

    pm = generate_preset_pass_manager(backend = backend, optimization_level=1)
    isa_circuito = pm.run(circuito_sem_medidas)
    isa_hamiltoniano = hamiltoniano.apply_layout(isa_circuito.layout)

    # Estimator:

    estimator = Estimator(mode=backend)

    # Job
    job = estimator.run([(isa_circuito, isa_hamiltoniano, )], precision = precisao)
    pub_result = job.result()[0]

    return pub_result.data.evs

# %% [markdown]
# # Estimativa de Fase
#
# O circuito da Estimativa de Fase:
# <center><img align = "center" src="https://drive.google.com/uc?export=view&id=1EfJsY9B4v9dI0K0nepSKQUprp7rNlaTz" alt="grafo" width="500"></center>
#
# Detalhamento das portas controladas:
# <center><img align = "center" src="https://drive.google.com/uc?export=view&id=1Pbn1Aed7NIAxSxRmt-2v2RfiuSlJv_h5" alt="grafo" width="500"></center>

# %%
# Métodos
import numpy as np
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
import qiskit.quantum_info as qi
from qiskit.circuit.library import QFT
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime.fake_provider import FakeBrisbane

def EstimativaFase(qc_unitario, qc_preparacao, num_qubits = int, num_qubits_aux = int, shots = None, backend = None):
    '''
    Função que implementa o algoritmo para Estimativa de Fase.

    Inputs:
        qc_unitario (QuantumCircuit)..: circuito quântico que que implementa o operador unitário
        qc_preparacao (QuantumCircuit): circuito quântico que prepara o auto-estado do operador unitário
        num_qubits (int)..........: número de qubits do circuito principal
        num_qubits_aux (int)......: número de qubits do circuito auxiliar
        shots (int)...............: número de medições (do registro auxiliar)
        backend...................: dispositivo para realização dos experimentos quânticos

    Output:
        fase (float): estimativa de fase

    Métodos requeridos:
        QuantumCircuit, QuantumRegister, ClassicalRegister
        qiskit.circuit.library.QFT
        qiskit_sampler(circuito_com_medidas, shots = None, backend = None)
        + dependências do qiskit_sampler
    '''

    if shots == None:
        shots = 1

    if backend == None:
        backend = FakeBrisbane()

    qr = QuantumRegister(num_qubits)
    qr_aux = QuantumRegister(num_qubits_aux)
    cr_aux = ClassicalRegister(num_qubits_aux)

    # Cria o circuito quântico
    qc = QuantumCircuit(qr, qr_aux, cr_aux)

    # Preparação do auto-estado
    qc.append(qc_preparacao, list(qr))

    # Aplicação de Hadamard nos qubits auxiliares
    for k in range(num_qubits_aux):
        qc.h(qr_aux[k])

    # Convert qc_unitario to a gate once for efficiency
    unitario_as_gate = qc_unitario.to_gate()

    # Aplicação das potências controladas do operador unitário

    # U^(2^0) = U:
    ctrl_gate_k0 = unitario_as_gate.control(1)

    # Aplicação de U^(2^k)-controlado
    qc.append(ctrl_gate_k0, [qr_aux[0]] + list(qr))

    # U^(2^k), para k = 1,..., num_qubits_aux -1:
    for k in range(1, num_qubits_aux):
        # Circuito que representa U^(2^k)
        qc_unitario_potencia = QuantumCircuit(num_qubits)
        for _ in range(2**k):
            qc_unitario_potencia.append(unitario_as_gate, list(range(num_qubits)))

        # Circuito de U^(2^k)-controlado
        ctrl_gate_potencia = qc_unitario_potencia.control(1)

        # Aplicação de U^(2^k)-controlado
        qc.append(ctrl_gate_potencia, [qr_aux[k]] + list(qr))

    # Aplicação da TFQ-inversa nos qubits auxiliares
    qc.append(QFT(num_qubits = num_qubits_aux, approximation_degree=0, do_swaps = True, inverse = True, insert_barriers = False, name= "QFTinv"), list(qr_aux))

    # Medida dos qubits auxiliares
    qc.measure(qr_aux, cr_aux)

    # Execução do algoritmo pelo Sampler
    medida = qiskit_sampler(qc, shots = shots, backend = backend)

    return medida[0]

# %% [markdown]
# ### TESTES

# %%
'''
Dígitos de um número decimal
'''

def decimal_to_binary(decimal_num):
    # Separate integer and fractional parts
    integer_part = int(decimal_num)
    fractional_part = decimal_num - integer_part

    # Convert integer part
    if integer_part == 0:
        binary_integer = "0"
    else:
        binary_integer = bin(integer_part)[2:] # [2:] removes the '0b' prefix

    # Convert fractional part
    binary_fractional = ""
    if fractional_part > 0:
        binary_fractional += "."
        for _ in range(10): # Limit to a reasonable number of binary places
            fractional_part *= 2
            bit = int(fractional_part)
            binary_fractional += str(bit)
            fractional_part -= bit
            if fractional_part == 0:
                break

    return binary_integer + binary_fractional

# Example usage
print(decimal_to_binary(1.0/2.0))
# Out:
# 0.1

# %% [markdown]
# ### Teste 2D

# %%
'''
Teste em 2D com o operador de fase
'''

# Entrada
fase = (1./2. + 1./8. + 1./32.)
print(f"Fase decimal: {fase}")
print(f"Fase binária: {decimal_to_binary(fase)}")

# Circuito do unitário
qc_unitario = QuantumCircuit(1)
qc_unitario.p(fase*2*np.pi, 0)
print("Circuito do unitário:")
display(qc_unitario.draw('mpl'))

# Circuito da preparação
qc_preparacao = QuantumCircuit(1)
qc_preparacao.x(0)
print("Circuito do unitário:a preparação:")
display(qc_preparacao.draw('mpl'))

# Informações adicionais
num_qubits = 1
num_qubits_aux = 7 # <-- Precisão em casas binárias: 'num_qubits_aux'
shots = 2**12

# Execução do algoritmo Estimativa de Fase
resultado = EstimativaFase(qc_unitario, qc_preparacao, num_qubits, num_qubits_aux, shots, backend = None)

# # Print do resultado:
# print("Resultado:")
# display(resultado)

# Identificação da fase:
keys = resultado.keys()
fase_estimada = '0'
counts = 0
for key in keys:
    resultado_key = resultado[key]
    if resultado_key > counts:
        fase_estimada = key
        counts = resultado_key

print(f"Dígitos da fase até a casa {num_qubits_aux}: {fase_estimada}")

# Plotagem do histograma
plot_histogram(resultado)
# Out:
# Fase decimal: 0.65625
# Fase binária: 0.10101
# Circuito do unitário:
# Circuito do unitário:a preparação:
# /tmp/ipython-input-2053317458.py:76: DeprecationWarning: The class ``qiskit.circuit.library.basis_change.qft.QFT`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. ('Use qiskit.circuit.library.QFTGate or qiskit.synthesis.qft.synth_qft_full instead, for access to all previous arguments.',)
#   qc.append(QFT(num_qubits = num_qubits_aux, approximation_degree=0, do_swaps = True, inverse = True, insert_barriers = False, name= "QFTinv"), list(qr_aux))
# Dígitos da fase até a casa 7: 1010100

# %% [markdown]
# ### Teste 3D
#
# Vetor unitário:
# $$
# \vec{u} = \begin{bmatrix}
# a\\
# b\\
# c
# \end{bmatrix},\ |\vec{u}| = \sqrt{a^2 + b^2 + c^2} = 1;
# $$
# Matriz da rotação do ângulo $\theta \in \mathbb{R}$ em torno de $\vec{u}$:
# $$
# R(\vec{u}, \theta) = \begin{bmatrix}
# \cos(\theta) + (1 - \cos(\theta))a^2 & (1 - \cos(\theta))ab + \sin(\theta)c & (1 - \cos(\theta))ac - \sin(\theta)b\\
# (1 - \cos(\theta)) ba - \sin(\theta)c & cos(\theta) + (1 - \cos(\theta))b^2 & (1 - \cos(\theta))bc + \sin(\theta)a\\
# (1 - \cos(\theta))ca + \sin(\theta)b & (1 - \cos(\theta))cb - \sin(\theta)a & \cos(\theta) + (1 - \cos(\theta))c^2
# \end{bmatrix}.
# $$
#
# ...
#
# $R(\vec{u}, \theta)$ é uma matriz unitária e $\vec{u}$ é um autovetor de $R(\vec{u}, \theta)$ associado ao autovalor $1$, logo a fase desse autovalor é $\lambda = 0$:
# $$
# R(\vec{u}, \theta)^\dagger = R(\vec{u}, \theta)^{-1}\ \ \text{e}\ \ R(\vec{u}, \theta)\vec{u} = \vec{u}.
# $$
#
# ⏬
#
# Como $\vec{u}$ é um vetor de dimensão $3$ e $R(\vec{u}, \theta)$ é uma matriz de dimensão $3\times 3$, para representá-los num registro quântico, temos que inseri-los no espaço $\mathbb{C}^4$. Assim, usando a mesma notação, escrevemos:
# $$
# \leadsto \vec{u} = \begin{bmatrix}
# a\\
# b\\
# c\\
# 0
# \end{bmatrix}
# $$
# e
# $$
# R(\vec{u}, \theta) = \begin{bmatrix}
# \cos(\theta) + (1 - \cos(\theta))a^2 & (1 - \cos(\theta))ab + \sin(\theta)c & (1 - \cos(\theta))ac - \sin(\theta)b & 0\\
# (1 - \cos(\theta)) ba - \sin(\theta)c & cos(\theta) + (1 - \cos(\theta))b^2 & (1 - \cos(\theta))bc + \sin(\theta)a & 0\\
# (1 - \cos(\theta))ca + \sin(\theta)b & (1 - \cos(\theta))cb - \sin(\theta)a & \cos(\theta) + (1 - \cos(\theta))c^2 & 0\\
# 0 & 0 & 0 & 1
# \end{bmatrix}.
# $$

# %%
# Vetor u e matriz de rotação R

import numpy as np

phi = np.pi/3
xi = np.pi/4
a = np.cos(phi); b = np.sin(phi)*np.cos(xi); c = np.sin(phi)*np.sin(xi)
u_vetor = [a, b, c, 0]
print(f"Vetor u: {u_vetor}")

theta = np.pi/6
R_matriz = np.array([[np.cos(theta) + (1 - np.cos(theta))*a**2, (1 - np.cos(theta))*a*b + np.sin(theta)*c, (1 - np.cos(theta))*a*c - np.sin(theta)*b, 0],
            [(1 - np.cos(theta))*b*a - np.sin(theta)*c, np.cos(theta) + (1 - np.cos(theta))*b**2, (1 - np.cos(theta))*b*c + np.sin(theta)*a, 0],
            [(1 - np.cos(theta))*c*a + np.sin(theta)*b, (1 - np.cos(theta))*c*b - np.sin(theta)*a, np.cos(theta) + (1 - np.cos(theta))*c**2, 0],
            [0, 0, 0, 1]])
print(f"Matriz R:")
display(R_matriz)

'''
Teste de Matriz unitária
'''

def is_unitary(matrix: np.ndarray, tolerancia: float) -> bool:

    unitary = True
    n = matrix.shape[0]
    error = np.linalg.norm(np.eye(n) - matrix.dot( matrix.transpose().conjugate()))

    if not(error < tolerancia):
        unitary = False

    return unitary

tolerance = 10**(-8)
print(f"Unitariedade de R_matriz: {is_unitary(R_matriz, tolerance)}")

'''
Teste de autovetor e autovalor
'''

eigenvalues, eigenvectors = np.linalg.eigh(R_matriz)
print(f"Autovalores: {eigenvalues}")
print(f"Autovetores: {eigenvectors}")
# Out:
# Vetor u: [np.float64(0.5000000000000001), np.float64(0.6123724356957946), np.float64(0.6123724356957945), 0]
# Matriz R:
# array([[ 0.89951905,  0.34720739, -0.26516504,  0.        ],
#        [-0.26516504,  0.91626588,  0.30024047,  0.        ],
#        [ 0.34720739, -0.19975953,  0.91626588,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])
# Unitariedade de R_matriz: True
# Autovalores: [0.54885578 0.72735405 1.         1.45584097]
# Autovetores: [[ 0.766376    0.1800662   0.         -0.61663927]
#  [ 0.22620881  0.82278227  0.          0.52140091]
#  [-0.60124654  0.53907838  0.         -0.58982802]
#  [-0.          0.          1.          0.        ]]

# %%
'''
Teste em 3D
    Input: matriz unitária real 3 x 3 (isometria: rotação ou reflexão)
    >>>>>  Possui autovalor 1, associado a um vetor invariante.
'''

# Entrada
fase = 0.
print(f"Fase decimal: {fase}")
print(f"Fase binária: {decimal_to_binary(fase)}")

# Circuito do unitário
import qiskit.quantum_info as qi

R_operador = qi.Operator(R_matriz)

qc_unitario = QuantumCircuit(2)
qc_unitario.unitary(R_operador, [0,1], label = "unitário")
print("Circuito do unitário:")
display(qc_unitario.draw('mpl'))

# Circuito da preparação
qc_preparacao = QuantumCircuit(2)
qc_preparacao.initialize(u_vetor, [0,1])

print("Circuito do unitário:a preparação:")
display(qc_preparacao.draw('mpl'))

# Informações adicionais
num_qubits = 2
num_qubits_aux = 5 # <-- Precisão em casas binárias: 'num_qubits_aux'
shots = 2**12

# Execução do algoritmo Estimativa de Fase
resultado = EstimativaFase(qc_unitario, qc_preparacao, num_qubits, num_qubits_aux, shots, backend = None)

# # Print do resultado:
# print("Resultado:")
# display(resultado)

# Identificação da fase:
keys = resultado.keys()
fase_estimada = '0'
counts = 0
for key in keys:
    resultado_key = resultado[key]
    if resultado_key > counts:
        fase_estimada = key
        counts = resultado_key

print(f"Fase estimada com dígitos até a casa {num_qubits_aux}: {fase_estimada}")

# Plotagem do histograma
plot_histogram(resultado)
# Out:
# Fase decimal: 0.0
# Fase binária: 0
# Circuito do unitário:
# Circuito do unitário:a preparação:
# /tmp/ipython-input-2454343894.py:76: DeprecationWarning: The class ``qiskit.circuit.library.basis_change.qft.QFT`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. ('Use qiskit.circuit.library.QFTGate or qiskit.synthesis.qft.synth_qft_full instead, for access to all previous arguments.',)
#   qc.append(QFT(num_qubits = num_qubits_aux, approximation_degree=0, do_swaps = True, inverse = True, insert_barriers = False, name= "QFTinv"), list(qr_aux))
# Fase estimada com dígitos até a casa 5: 00000
